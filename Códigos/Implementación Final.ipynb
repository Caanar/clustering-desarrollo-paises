# %%
# Se importan librerías principales
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Se cargan los datos (como se vio en los descriptivos, los datos vienen limpios)
df = pd.read_csv("C:/Users/CArrieta/Downloads/Country-data.csv")
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
# Se realiza el Análisis de Componentes principales, conservando el número de componentes que explica al menos el 90% de la varianza.
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
df_est = StandardScaler().fit_transform(df.iloc[:,1:])
pca_estimator = PCA(n_components=5)
pca_estimator.fit(df_est)
print("Varianza Explicada por 5 componentes: {}%".format(pca_estimator.explained_variance_ratio_.sum()*100))
pca_data = pd.DataFrame(pca_estimator.transform(df_est))
# Out:
# Varianza Explicada por 5 componentes: 94.53099756439514%

# %%
# Se grafican los coeficientes de silhouette y los elbow plots para elegir el número de clusters en K-Medias y K-Medoides
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids 
from sklearn.metrics import silhouette_score
print("Elección de Clusters para K-Medias:")
varianza_intra_cluster = []
silhouettes = []
for k in range (1, 50):
    kmeans = KMeans(n_clusters = k, random_state = 123).fit(pca_data)
    varianza_intra_cluster.append(kmeans.inertia_)
    try:
        silhouette = silhouette_score(pca_data, kmeans.labels_)
    except:
        silhouette = 0
    silhouettes.append(silhouette)
plt.plot(range(1, 50), silhouettes, marker='o')
plt.xlabel('Número de clústeres (K)')
plt.ylabel('Índice de Silhouette')
plt.show()

plt.plot(range(1, 50), varianza_intra_cluster, marker='o')
plt.xlabel('Número de clústeres (K)')
plt.ylabel('Varianza intra clúster')
plt.show()

print("Elección de Clusters para K-Medoides:")
varianza_intra_cluster = []
silhouettes = []
for k in range (1, 50):
    kmedoids = KMedoids(n_clusters = k, random_state = 123).fit(pca_data)
    varianza_intra_cluster.append(kmedoids.inertia_)
    try:
        silhouette = silhouette_score(pca_data, kmedoids.labels_)
    except:
        silhouette = 0
    silhouettes.append(silhouette)
plt.plot(range(1, 50), silhouettes, marker='o')
plt.xlabel('Número de clústeres (K)')
plt.ylabel('Índice de Silhouette')
plt.show()

plt.plot(range(1, 50), varianza_intra_cluster, marker='o')
plt.xlabel('Número de clústeres (K)')
plt.ylabel('Varianza intra clúster')
plt.show()
# Out:
# Elección de Clusters para K-Medias:
# Elección de Clusters para K-Medoides:

# %%
from sklearn.metrics import accuracy_score
inert = []
for e in range(1,30):
    kmeans = KMeans(n_clusters = 6, random_state = e).fit(pca_data)
    inert.append(kmeans.inertia_)
    kmeans = kmeans.predict(pca_data)
print("\nDescriptivos sobre la inercia de los modelos de K-Medias sobre los datos resultado del PCA:")
print(pd.DataFrame(inert).describe())
kmeans = KMeans(n_clusters = 6, random_state = 18).fit_predict(pca_data) # Se elige el estado aleatorio 18 por ser el que menos varianza intra_cluster muestra
df['Cluster'] = kmeans
clusters_lst = []
for cluster in df['Cluster'].unique():
    clusterls = []
    for entry in df.iterrows():
        if entry[1]['Cluster'] == cluster:
            clusterls.append(entry[1]['country'])
    clusters_lst.append(clusterls)
print("\nPaises por Cluster de acuerdo con los 10 clusters en K-Medias:")
print(pd.DataFrame(clusters_lst).T.rename(columns={0:'Cluster 1',1:'Cluster 2',2:'Cluster 3',3:'Cluster 4',4:'Cluster 5',5:'Cluster 6',6:'Cluster 7',7:'Cluster 8',8:'Cluster 9',9:'Cluster 10'}))
df['Cluster'] = df['Cluster'].replace({0:'Cluster 1',1:'Cluster 2',2:'Cluster 3',3:'Cluster 4',4:'Cluster 5',5:'Cluster 6',6:'Cluster 7',7:'Cluster 8',8:'Cluster 9',9:'Cluster 10'})
for e in df.columns:
    if e not in ['country', 'Cluster']:
        print("\nDescriptivos por cluster para {}:".format(e))
        print(df.groupby('Cluster')[e].describe().round(2))
# Out:
# Descriptivos sobre la inercia de los modelos de K-Medias sobre los datos resultado del PCA:
#                 0
# count   29.000000
# mean   476.153370
# std      8.329018
# min    469.703424
# 25%    470.051399
# 50%    470.131501
# 75%    481.682869
# max    497.058167
#
# Paises por Cluster de acuerdo con los 10 clusters en K-Medias:
#                    Cluster 1               Cluster 2  \
# 0                Afghanistan                 Albania
# 1                     Angola     Antigua and Barbuda
# 2                      Benin                 Bahamas
# 3                   Botswana                 Bahrain
# 4               Burkina Faso                Barbados
# 5                    Burundi                 Belarus
# 6                   Cameroon                  Belize
# 7   Central African Republic                  Bhutan
# 8                       Chad  Bosnia and Herzegovina
# 9                    Comoros                Bulgaria
# 10          Congo, Dem. Rep.                Cambodia
# 11               Congo, Rep.              Costa Rica
# 12             Cote d'Ivoire                 Croatia
# 13         Equatorial Guinea                  Cyprus
# 14                   Eritrea          Czech Republic
# 15                    Gambia                 Estonia
# 16                     Ghana                    Fiji
# 17                    Guinea                 Georgia
# 18             Guinea-Bissau                  Guyana
# 19                     Haiti                 Hungary
# 20                     Kenya                  Jordan
# 21                  Kiribati         Kyrgyz Republic
# 22                       Lao                  Latvia
# 23                   Lesotho                 Lebanon
# 24                   Liberia               Lithuania
# 25                Madagascar          Macedonia, FYR
# 26                    Malawi                Malaysia
# 27                      Mali                Maldives
# 28                Mauritania               Mauritius
# 29                Mozambique   Micronesia, Fed. Sts.
# 30                   Namibia                 Moldova
# 31                     Niger              Montenegro
# 32                  Pakistan                  Panama
# 33                    Rwanda                Paraguay
# 34                   Senegal                  Poland
# 35              Sierra Leone                  Serbia
# 36              South Africa              Seychelles
# 37                     Sudan         Slovak Republic
# 38                  Tanzania                Slovenia
# 39               Timor-Leste         Solomon Islands
# 40                      Togo             South Korea
# 41                    Uganda                Thailand
# 42                     Yemen                 Tunisia
# 43                    Zambia                 Ukraine
# 44                      None                 Vietnam
#
#                          Cluster 3             Cluster 4   Cluster 5  \
# 0                          Algeria             Australia  Luxembourg
# 1                        Argentina               Austria       Malta
# 2                          Armenia               Belgium   Singapore
# 3                       Azerbaijan                Brunei        None
# 4                       Bangladesh                Canada        None
# 5                          Bolivia               Denmark        None
# 6                           Brazil               Finland        None
# 7                       Cape Verde                France        None
# 8                            Chile               Germany        None
# 9                            China                Greece        None
# 10                        Colombia               Iceland        None
# 11              Dominican Republic               Ireland        None
# 12                         Ecuador                Israel        None
# 13                           Egypt                 Italy        None
# 14                     El Salvador                 Japan        None
# 15                           Gabon                Kuwait        None
# 16                         Grenada           Netherlands        None
# 17                       Guatemala           New Zealand        None
# 18                           India                Norway        None
# 19                       Indonesia              Portugal        None
# 20                            Iran                 Qatar        None
# 21                            Iraq                 Spain        None
# 22                         Jamaica                Sweden        None
# 23                      Kazakhstan           Switzerland        None
# 24                           Libya  United Arab Emirates        None
# 25                         Morocco        United Kingdom        None
# 26                         Myanmar         United States        None
# 27                           Nepal                  None        None
# 28                            Oman                  None        None
# 29                            Peru                  None        None
# 30                     Philippines                  None        None
# 31                         Romania                  None        None
# 32                          Russia                  None        None
# 33                           Samoa                  None        None
# 34                    Saudi Arabia                  None        None
# 35                       Sri Lanka                  None        None
# 36  St. Vincent and the Grenadines                  None        None
# 37                        Suriname                  None        None
# 38                      Tajikistan                  None        None
# 39                           Tonga                  None        None
# 40                          Turkey                  None        None
# 41                    Turkmenistan                  None        None
# 42                         Uruguay                  None        None
# 43                      Uzbekistan                  None        None
# 44                         Vanuatu                  None        None
#
#     Cluster 6
# 0    Mongolia
# 1     Nigeria
# 2   Venezuela
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# 30       None
# 31       None
# 32       None
# 33       None
# 34       None
# 35       None
# 36       None
# 37       None
# 38       None
# 39       None
# 40       None
# 41       None
# 42       None
# 43       None
# 44       None
#
# Descriptivos por cluster para child_mort:
#            count   mean    std   min    25%    50%     75%    max
# Cluster
# Cluster 1   27.0   5.10   2.23   2.6   3.90   4.30    5.40   10.8
# Cluster 2   44.0  94.06  32.64  52.5  66.07  90.25  111.00  208.0
# Cluster 3   45.0  14.91  10.71   3.2   6.90  11.70   18.80   44.4
# Cluster 4    3.0  57.73  62.75  17.1  21.60  26.10   78.05  130.0
# Cluster 5   45.0  27.96  15.44   8.7  17.40  21.50   35.40   64.4
# Cluster 6    3.0   4.13   2.31   2.8   2.80   2.80    4.80    6.8
#
# Descriptivos por cluster para exports:
#            count    mean    std     min     25%    50%     75%    max
# Cluster
# Cluster 1   27.0   44.85  22.62   12.40   27.50   39.7   63.15  103.0
# Cluster 2   44.0   28.36  18.18    2.20   16.73   23.3   36.85   85.8
# Cluster 3   45.0   52.64  16.62   23.50   39.50   50.5   65.30   93.8
# Cluster 4    3.0   33.50  11.54   25.30   26.90   28.5   37.60   46.7
# Cluster 5   45.0   31.32  15.89    0.11   21.30   27.8   38.40   76.3
# Cluster 6    3.0  176.00  23.52  153.00  164.00  175.0  187.50  200.0
#
# Descriptivos por cluster para health:
#            count  mean   std   min   25%   50%    75%    max
# Cluster
# Cluster 1   27.0  9.36  3.36  1.81  9.07  9.63  11.15  17.90
# Cluster 2   44.0  6.44  2.69  2.20  4.53  5.68   8.01  13.10
# Cluster 3   45.0  7.26  2.16  3.40  5.97  6.93   8.04  14.20
# Cluster 4    3.0  5.14  0.27  4.91  4.99  5.07   5.26   5.44
# Cluster 5   45.0  5.33  1.74  1.97  4.17  5.08   6.47   9.01
# Cluster 6    3.0  6.79  2.49  3.96  5.86  7.77   8.21   8.65
#
# Descriptivos por cluster para imports:
#            count    mean    std     min     25%    50%     75%    max
# Cluster
# Cluster 1   27.0   37.98  17.39   13.60   28.00   31.0   43.45   86.5
# Cluster 2   44.0   43.61  17.49   17.20   30.67   42.8   50.03  101.0
# Cluster 3   45.0   62.16  14.13   35.00   51.50   60.8   70.70  108.0
# Cluster 4    3.0   30.57  22.63   17.40   17.50   17.6   37.15   56.7
# Cluster 5   45.0   33.95  13.77    0.07   23.80   33.0   43.00   61.8
# Cluster 6    3.0  156.67  16.17  142.00  148.00  154.0  164.00  174.0
#
# Descriptivos por cluster para income:
#            count      mean       std      min      25%      50%      75%  \
# Cluster
# Cluster 1   27.0  46833.33  20249.75  27200.0  36200.0  41100.0  47550.0
# Cluster 2   44.0   3455.52   5379.35    609.0   1380.0   1835.0   3290.0
# Cluster 3   45.0  14990.67   9011.62   1780.0   7820.0  14000.0  21100.0
# Cluster 4    3.0   9786.67   5953.15   5150.0   6430.0   7710.0  12105.0
# Cluster 5   45.0  12235.11   9463.68   1990.0   5830.0   9920.0  16000.0
# Cluster 6    3.0  64033.33  32460.64  28300.0  50200.0  72100.0  81900.0
#
#                 max
# Cluster
# Cluster 1  125000.0
# Cluster 2   33700.0
# Cluster 3   41100.0
# Cluster 4   16500.0
# Cluster 5   45400.0
# Cluster 6   91700.0
#
# Descriptivos por cluster para inflation:
#            count   mean    std    min    25%    50%    75%     max
# Cluster
# Cluster 1   27.0   2.89   4.44  -3.22   0.66   1.16   3.48   16.70
# Cluster 2   44.0   9.72   7.36   0.88   3.79   8.22  14.52   26.50
# Cluster 3   45.0   3.93   4.11  -4.21   1.14   2.88   6.10   15.10
# Cluster 4    3.0  63.03  35.64  39.20  42.55  45.90  74.95  104.00
# Cluster 5   45.0   9.35   5.99   0.48   4.44   7.77  15.10   22.80
# Cluster 6    3.0   2.47   2.18  -0.05   1.79   3.62   3.72    3.83
#
# Descriptivos por cluster para life_expec:
#            count   mean   std   min    25%    50%    75%   max
# Cluster
# Cluster 1   27.0  80.44  1.51  76.5  79.90  80.50  81.45  82.8
# Cluster 2   44.0  58.89  6.52  32.1  56.45  59.05  62.35  71.1
# Cluster 3   45.0  74.01  4.31  61.7  72.80  74.50  76.70  80.4
# Cluster 4    3.0  67.37  7.52  60.5  63.35  66.20  70.80  75.4
# Cluster 5   45.0  72.07  3.88  62.9  69.20  71.60  74.70  79.1
# Cluster 6    3.0  81.43  1.21  80.3  80.80  81.30  82.00  82.7
#
# Descriptivos por cluster para total_fer:
#            count  mean   std   min   25%   50%   75%   max
# Cluster
# Cluster 1   27.0  1.84  0.36  1.37  1.50  1.87  2.00  3.03
# Cluster 2   44.0  5.02  1.06  2.59  4.58  5.08  5.60  7.49
# Cluster 3   45.0  1.99  0.69  1.23  1.49  1.77  2.23  4.24
# Cluster 4    3.0  3.65  1.90  2.47  2.56  2.64  4.24  5.84
# Cluster 5   45.0  2.60  0.72  1.57  2.15  2.52  2.90  4.56
# Cluster 6    3.0  1.38  0.24  1.15  1.25  1.36  1.50  1.63
#
# Descriptivos por cluster para gdpp:
#            count      mean       std      min       25%      50%      75%  \
# Cluster
# Cluster 1   27.0  45322.22  14475.27  22500.0  35550.00  44400.0  49500.0
# Cluster 2   44.0   1699.36   2838.11    231.0    532.25    763.5   1310.0
# Cluster 3   45.0   9089.69   7439.51    786.0   3650.00   6840.0  12600.0
# Cluster 4    3.0   6160.00   6358.64   2330.0   2490.00   2650.0   8075.0
# Cluster 5   45.0   5918.36   4486.93    592.0   2830.00   4560.0   8300.0
# Cluster 6    3.0  57566.67  43011.67  21100.0  33850.00  46600.0  75800.0
#
#                 max
# Cluster
# Cluster 1   87800.0
# Cluster 2   17100.0
# Cluster 3   30800.0
# Cluster 4   13500.0
# Cluster 5   19300.0
# Cluster 6  105000.0

# %%
import seaborn as sns
sns.pairplot(df, hue='Cluster')
plt.show()

# %% [markdown]
# K-medoides

# %%
df_final= df.set_index("country").drop('Cluster', axis=1)

# %%
df_final.head()
# Out:
#                      child_mort  exports  health  imports  income  inflation  \
# country
# Afghanistan                90.2     10.0    7.58     44.9    1610       9.44
# Albania                    16.6     28.0    6.55     48.6    9930       4.49
# Algeria                    27.3     38.4    4.17     31.4   12900      16.10
# Angola                    119.0     62.3    2.85     42.9    5900      22.40
# Antigua and Barbuda        10.3     45.5    6.03     58.9   19100       1.44
#
#                      life_expec  total_fer   gdpp
# country
# Afghanistan                56.2       5.82    553
# Albania                    76.3       1.65   4090
# Algeria                    76.5       2.89   4460
# Angola                     60.1       6.16   3530
# Antigua and Barbuda        76.8       2.13  12200

# %%
Dos_medoides = KMedoids(n_clusters = 10, random_state = 0).fit_predict(df_final)

# %%
df_final["cluster"]=Dos_medoides

# %%
df_final.groupby("cluster").describe()
# Out:
#         child_mort                                                             \
#              count       mean        std   min     25%    50%      75%    max
# cluster
# 0              9.0  25.877778  18.045206   6.8  14.600  18.60   36.900   53.7
# 1             18.0  10.622222   5.051797   4.5   6.325   9.35   14.350   21.5
# 2             13.0  22.530769  13.980724   6.9  15.700  20.30   25.100   62.0
# 3             12.0  20.758333  16.155858   5.5  10.675  17.15   20.875   63.7
# 4              3.0  30.966667  21.682328  18.1  18.450  18.80   37.400   56.0
# 5             18.0  51.327778  33.982207  17.2  27.175  38.80   62.625  130.0
# 6             24.0   5.037500   2.408646   2.6   3.200   4.25    5.300   10.8
# 7             16.0  13.806250  26.327184   3.2   3.875   5.40   12.225  111.0
# 8             42.0  89.773810  36.478407  28.1  62.925  88.75  110.500  208.0
# 9             12.0  24.658333   9.930894  11.2  17.700  24.10   33.350   42.7
#
#         exports             ... total_fer        gdpp                \
#           count       mean  ...       75%   max count          mean
# cluster                     ...
# 0           9.0  36.233333  ...    2.8800  4.56   9.0   5931.111111
# 1          18.0  50.044444  ...    2.1500  2.60  18.0  12268.888889
# 2          13.0  38.700000  ...    2.6600  3.66  13.0   4701.538462
# 3          12.0  43.666667  ...    2.0700  4.08  12.0   7905.000000
# 4           3.0  45.766667  ...    3.1550  3.60   3.0   4736.666667
# 5          18.0  38.272222  ...    4.2325  6.16  18.0   2280.555556
# 6          24.0  60.129167  ...    1.9575  2.21  24.0  51287.500000
# 7          16.0  56.056250  ...    2.5325  5.21  16.0  23631.250000
# 8          42.0  24.076167  ...    5.5275  7.49  42.0    836.285714
# 9          12.0  36.150000  ...    2.6475  3.38  12.0   2952.500000
#
#
#                   std      min       25%      50%      75%       max
# cluster
# 0         1114.455522   4460.0   5080.00   6250.0   6680.0    7370.0
# 1         2099.276875   9070.0  10725.00  12100.0  13400.0   16600.0
# 2         1118.941808   2600.0   4140.00   4560.0   5020.0    7100.0
# 3         1467.096700   5840.0   6762.50   8140.0   8412.5   11200.0
# 4          427.823951   4340.0   4510.00   4680.0   4935.0    5190.0
# 5          911.956347   1040.0   1357.50   2230.0   3022.5    3550.0
# 6        17107.138416  35000.0  41500.00  46750.0  51950.0  105000.0
# 7         5930.567005  12100.0  19675.00  22300.0  28650.0   33700.0
# 8          559.151766    231.0    502.75    705.0    997.0    3600.0
# 9          356.781701   2180.0   2825.00   2965.0   3137.5    3650.0
#
# [10 rows x 72 columns]

# %%
for e in df_final.columns:
    if e not in ['country', 'cluster']:
        print("\nDescriptivos por cluster para {}:".format(e))
        print(df_final.groupby('cluster')[e].describe().round(2))
# Out:
# Descriptivos por cluster para child_mort:
#          count   mean    std   min    25%    50%     75%    max
# cluster
# 0          9.0  25.88  18.05   6.8  14.60  18.60   36.90   53.7
# 1         18.0  10.62   5.05   4.5   6.32   9.35   14.35   21.5
# 2         13.0  22.53  13.98   6.9  15.70  20.30   25.10   62.0
# 3         12.0  20.76  16.16   5.5  10.68  17.15   20.88   63.7
# 4          3.0  30.97  21.68  18.1  18.45  18.80   37.40   56.0
# 5         18.0  51.33  33.98  17.2  27.18  38.80   62.62  130.0
# 6         24.0   5.04   2.41   2.6   3.20   4.25    5.30   10.8
# 7         16.0  13.81  26.33   3.2   3.88   5.40   12.22  111.0
# 8         42.0  89.77  36.48  28.1  62.92  88.75  110.50  208.0
# 9         12.0  24.66   9.93  11.2  17.70  24.10   33.35   42.7
#
# Descriptivos por cluster para exports:
#          count   mean    std    min    25%    50%    75%    max
# cluster
# 0          9.0  36.23  14.24  15.90  28.60  37.00  39.40   66.5
# 1         18.0  50.04  23.92  18.90  31.30  42.15  72.65   93.8
# 2         13.0  38.70  19.24  21.30  26.90  28.00  48.30   77.6
# 3         12.0  43.67  16.49  10.70  33.05  50.70  52.95   70.0
# 4          3.0  45.77  13.56  31.30  39.55  47.80  53.00   58.2
# 5         18.0  38.27  19.28  12.40  26.28  33.75  45.25   85.1
# 6         24.0  60.13  45.34  12.40  28.88  50.90  68.55  200.0
# 7         16.0  56.06  31.89  22.10  33.83  49.90  65.78  153.0
# 8         42.0  24.08  13.98   0.11  15.00  21.45  31.20   54.1
# 9         12.0  36.15  13.34  19.60  25.42  33.60  46.80   57.8
#
# Descriptivos por cluster para health:
#          count  mean   std   min   25%   50%    75%    max
# cluster
# 0          9.0  7.41  2.27  3.88  5.86  8.30   8.94  10.40
# 1         18.0  6.57  1.59  3.40  5.32  6.89   7.91   8.79
# 2         13.0  6.26  2.11  2.50  5.07  6.22   7.09  11.10
# 3         12.0  6.76  1.91  3.50  5.61  6.44   7.30  10.90
# 4          3.0  5.60  1.04  4.81  5.00  5.20   5.99   6.78
# 5         18.0  5.53  3.01  2.20  4.06  5.07   5.70  14.20
# 6         24.0  9.00  3.70  1.81  8.49  9.51  11.32  17.90
# 7         16.0  7.23  2.57  2.77  4.85  7.76   9.44  11.00
# 8         42.0  6.54  2.62  1.97  4.94  5.79   7.85  13.10
# 9         12.0  5.68  2.05  2.61  4.75  5.32   6.86  10.10
#
# Descriptivos por cluster para imports:
#          count   mean    std    min    25%    50%    75%    max
# cluster
# 0          9.0  42.51  15.52  17.80  31.40  47.90  51.30   62.7
# 1         18.0  48.83  25.68  16.00  26.60  45.40  68.32  108.0
# 2         13.0  45.23  15.95  22.60  32.40  48.60  57.10   69.0
# 3         12.0  41.76  21.66  11.80  20.38  38.60  60.70   78.2
# 4          3.0  55.93   5.71  49.60  53.55  57.50  59.10   60.7
# 5         18.0  49.52  21.03  17.40  34.32  51.00  61.42   81.0
# 6         24.0  49.40  38.30  13.60  28.08  37.25  55.87  174.0
# 7         16.0  50.57  30.12  26.80  32.98  42.90  57.85  154.0
# 8         42.0  44.26  20.50   0.07  30.22  41.50  51.18  101.0
# 9         12.0  47.26  14.01  22.40  41.32  48.85  53.77   70.7
#
# Descriptivos por cluster para income:
#          count      mean       std      min      25%      50%      75%  \
# cluster
# 0          9.0  12577.78   1035.35  10900.0  12000.0  12700.0  13300.0
# 1         18.0  20016.67   2515.42  15300.0  18400.0  20100.0  21625.0
# 2         13.0  10083.08    614.35   9350.0   9720.0   9930.0  10400.0
# 3         12.0  15616.67   1323.79  13000.0  15100.0  15650.0  16225.0
# 4          3.0   8113.33    306.16   7880.0   7940.0   8000.0   8230.0
# 5         18.0   4743.33    872.02   2950.0   4250.0   4735.0   5407.5
# 6         24.0  53250.00  21766.23  35800.0  40250.0  43600.0  58775.0
# 7         16.0  32368.75   6392.78  22900.0  28600.0  30000.0  33750.0
# 8         42.0   1859.60    793.85    609.0   1360.0   1755.0   2425.0
# 9         12.0   7288.33    729.32   6420.0   6707.5   7295.0   7737.5
#
#               max
# cluster
# 0         14000.0
# 1         25200.0
# 2         11400.0
# 3         17800.0
# 4          8460.0
# 5          5900.0
# 6        125000.0
# 7         45400.0
# 8          3720.0
# 9          8560.0
#
# Descriptivos por cluster para inflation:
#          count   mean    std   min   25%   50%    75%     max
# cluster
# 0          9.0   7.10   5.81  0.48  3.86  5.88   8.92   16.60
# 1         18.0   7.49  11.78 -4.21  0.98  2.36   8.54   45.90
# 2         13.0   5.04   2.64  1.40  2.88  4.49   6.94   10.10
# 3         12.0   7.68   6.22  0.24  2.22  6.88  14.13   16.60
# 4          3.0   4.84   4.47  1.14  2.35  3.56   6.68    9.81
# 5         18.0  15.03  23.30  0.50  3.90  9.09  15.40  104.00
# 6         24.0   3.11   4.67 -3.22  0.66  1.19   4.08   16.70
# 7         16.0   5.78   7.88 -1.43  0.52  2.58   9.13   24.90
# 8         42.0   8.55   6.28  0.88  3.31  6.92  12.25   26.50
# 9         12.0  11.01  10.76  0.98  4.91  6.94  13.88   39.20
#
# Descriptivos por cluster para life_expec:
#          count   mean   std   min    25%    50%    75%   max
# cluster
# 0          9.0  70.06  8.75  54.3  67.20  74.70  76.40  76.6
# 1         18.0  74.93  2.74  68.4  73.68  75.65  76.38  79.1
# 2         13.0  74.73  3.05  67.9  74.00  75.80  76.80  77.9
# 3         12.0  73.37  4.85  62.9  70.38  73.80  75.32  80.4
# 4          3.0  68.23  8.50  58.6  65.00  71.40  73.05  74.7
# 5         18.0  66.88  4.20  60.1  64.18  66.85  69.85  73.1
# 6         24.0  80.48  1.63  76.5  79.88  80.60  81.55  82.8
# 7         16.0  77.48  5.07  60.9  76.07  79.65  80.32  81.9
# 8         42.0  59.87  7.27  32.1  56.58  60.10  65.28  71.1
# 9         12.0  71.45  3.04  65.3  70.28  72.45  73.65  74.4
#
# Descriptivos por cluster para total_fer:
#          count  mean   std   min   25%   50%   75%   max
# cluster
# 0          9.0  2.43  0.97  1.40  1.77  2.24  2.88  4.56
# 1         18.0  1.86  0.41  1.25  1.51  1.83  2.15  2.60
# 2         13.0  2.30  0.70  1.31  1.65  2.23  2.66  3.66
# 3         12.0  2.04  0.74  1.49  1.59  1.78  2.07  4.08
# 4          3.0  2.83  0.72  2.17  2.44  2.71  3.16  3.60
# 5         18.0  3.54  1.29  1.27  2.66  3.33  4.23  6.16
# 6         24.0  1.79  0.28  1.15  1.60  1.87  1.96  2.21
# 7         16.0  2.13  1.03  1.23  1.41  1.72  2.53  5.21
# 8         42.0  4.88  1.20  2.33  4.30  5.06  5.53  7.49
# 9         12.0  2.36  0.52  1.44  2.13  2.43  2.65  3.38
#
# Descriptivos por cluster para gdpp:
#          count      mean       std      min       25%      50%      75%  \
# cluster
# 0          9.0   5931.11   1114.46   4460.0   5080.00   6250.0   6680.0
# 1         18.0  12268.89   2099.28   9070.0  10725.00  12100.0  13400.0
# 2         13.0   4701.54   1118.94   2600.0   4140.00   4560.0   5020.0
# 3         12.0   7905.00   1467.10   5840.0   6762.50   8140.0   8412.5
# 4          3.0   4736.67    427.82   4340.0   4510.00   4680.0   4935.0
# 5         18.0   2280.56    911.96   1040.0   1357.50   2230.0   3022.5
# 6         24.0  51287.50  17107.14  35000.0  41500.00  46750.0  51950.0
# 7         16.0  23631.25   5930.57  12100.0  19675.00  22300.0  28650.0
# 8         42.0    836.29    559.15    231.0    502.75    705.0    997.0
# 9         12.0   2952.50    356.78   2180.0   2825.00   2965.0   3137.5
#
#               max
# cluster
# 0          7370.0
# 1         16600.0
# 2          7100.0
# 3         11200.0
# 4          5190.0
# 5          3550.0
# 6        105000.0
# 7         33700.0
# 8          3600.0
# 9          3650.0

# %% [markdown]
# # CLUSTER JERARQUICO

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp    Cluster
# 0         9.44        56.2       5.82    553  Cluster 2
# 1         4.49        76.3       1.65   4090  Cluster 3
# 2        16.10        76.5       2.89   4460  Cluster 5
# 3        22.40        60.1       6.16   3530  Cluster 2
# 4         1.44        76.8       2.13  12200  Cluster 3
# ..         ...         ...        ...    ...        ...
# 162       2.62        63.0       3.50   2970  Cluster 5
# 163      45.90        75.4       2.47  13500  Cluster 4
# 164      12.10        73.1       1.95   1310  Cluster 3
# 165      23.60        67.5       4.67   1310  Cluster 2
# 166      14.00        52.0       5.40   1460  Cluster 2
#
# [167 rows x 11 columns]

# %%
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN

# %%
df["id"] = df.index + 1

# %%
X= df.drop('country',axis=1)

# %%
data= X.drop('Cluster',axis=1)

# %%
data
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp   id
# 0         5.82    553    1
# 1         1.65   4090    2
# 2         2.89   4460    3
# 3         6.16   3530    4
# 4         2.13  12200    5
# ..         ...    ...  ...
# 162       3.50   2970  163
# 163       2.47  13500  164
# 164       1.95   1310  165
# 165       4.67   1310  166
# 166       5.40   1460  167
#
# [167 rows x 10 columns]

# %%
sns.clustermap(data)

# %%
import matplotlib
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
import numpy as np

# %%
matplotlib.rc_file_defaults()
X = data[['income', 'health']].to_numpy()
dist = pdist(X, metric='euclidean')
Z = linkage(dist, method='ward')

fig, ax = plt.subplots(figsize=(25, 25))
d = dendrogram(Z, show_leaf_counts=True, leaf_font_size=9, ax=ax)
ax.set_xlabel('Observaciones', fontsize=9)
ax.set_yticks(np.arange(0, 450_000, 50_000))
ax.set_ylabel('Distancia', fontsize=9)
plt.show()

# %% [markdown]
# Fijando la distancia en 80

# %%
cluster = AgglomerativeClustering(n_clusters=None,
                                  affinity='euclidean',
                                  linkage='ward',
                                  compute_full_tree=True,
                                  distance_threshold=80_000)

cluster.fit_predict(X)

print(f"Clusters a conformar = {cluster.n_clusters_}")
# Out:
# Clusters a conformar = 4

# %%
cluster_sk = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
cluster_sk = cluster_sk.fit_predict(X)

# %%
matplotlib.rc_file_defaults()
plt.scatter(X[:,0], X[:,1], c=cluster_sk, cmap='tab20b')
plt.show()
